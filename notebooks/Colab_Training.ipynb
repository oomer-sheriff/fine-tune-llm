# %% [markdown]
# # Tamil LLM Fine-Tuning Workspace (Google Colab)
#
# This notebook provides a complete environment to train a Tamil LLM using QLoRA and Unsloth.

# %%
# !git clone https://github.com/oomer-sheriff/fine-tune-llm.git
# %cd fine-tune-llm
# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# 2. Install Dependencies
# !pip install unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git
# !pip install -r requirements.txt

# %%
# 3. Start or Resume Training
# If this is your first run, it will start fresh.
# If Colab disconnected, just run all cells again and it will auto-resume!
# !python scripts/resume_training.py --dataset datasets/examples/sample.jsonl

# %%
# 4. Evaluate (Optional)
# !python evaluate.py --adapter_path /content/drive/MyDrive/Tamil-LLM/final_adapter --eval_dataset datasets/examples/sample.jsonl
