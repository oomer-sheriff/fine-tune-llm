# %% [markdown]
# # Tamil LLM Fine-Tuning Workspace (Kaggle)
#
# This notebook uses Kaggle's `/kaggle/working/` directory for saving checkpoints.

# %%
# 1. Install Dependencies
# !pip install unsloth[kaggle-new] @ git+https://github.com/unslothai/unsloth.git
# !pip install -r requirements.txt

# %%
# 2. Modify config to use Kaggle working directory instead of Google Drive
import yaml
with open('configs/train_config.yaml', 'r') as f:
    config = yaml.safe_load(f)
config['storage']['drive_path'] = '/kaggle/working/Tamil-LLM'
with open('configs/train_config.yaml', 'w') as f:
    yaml.dump(config, f)

# %%
# 3. Start or Resume Training
# !python scripts/resume_training.py --dataset datasets/examples/sample.jsonl
